# %%
import sys
import os

# Add project root to Python path
sys.path.append(os.path.abspath(".."))

# %%
import pandas as pd
from src.features import create_features
from src.data_utils import save_processed

df = pd.read_csv("../data/processed/house_prices_v1.csv")
df = create_features(df)
save_processed(df, "house_prices_feature_v2.csv")
df[["price_per_sqft","carpet_super_ratio","floor_num","location_clean","has_plot_area"]].head()
# Out:
#    price_per_sqft  carpet_super_ratio  floor_num location_clean  has_plot_area
# 0     8400.000000                 NaN       10.0          thane          False
# 1    20718.816068                 NaN        3.0          thane          False
# 2    17971.758665                 NaN       10.0          thane          False
# 3     4716.981132                 NaN        1.0          thane          False
# 4    25196.850394                 NaN       20.0          thane          False
